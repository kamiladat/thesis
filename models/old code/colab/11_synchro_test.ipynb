# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
import pandas as pd
from torch.utils.data import Dataset, DataLoader
import torch
import numpy as np

# Load datasets
def load_datasets():
    audio_train_df = pd.read_csv('/content/drive/MyDrive/1sec/SEWA_features_wav2vec_1_seconds_train.csv')
    audio_dev_df = pd.read_csv('/content/drive/MyDrive/1sec/SEWA_features_wav2vec_1_seconds_dev.csv')
    audio_test_df = pd.read_csv('/content/drive/MyDrive/1sec/SEWA_features_wav2vec_1_seconds_test.csv')

    video_train_df = pd.read_csv('/content/drive/MyDrive/SEWA_radiant_fog_160_train.csv')
    video_dev_df = pd.read_csv('/content/drive/MyDrive/SEWA_radiant_fog_160_dev.csv')
    video_test_df = pd.read_csv('/content/drive/MyDrive/SEWA_radiant_fog_160_test.csv')

    return audio_train_df, audio_dev_df, audio_test_df, video_train_df, video_dev_df, video_test_df

# Define custom Dataset
class SynchronizedAVDataset(Dataset):
    def __init__(self, audio_df, video_df, window_size_sec=2, stride_sec=1, max_video_frames=6):
        self.audio_df = audio_df
        self.video_df = video_df
        self.window_size_sec = window_size_sec
        self.stride_sec = stride_sec
        self.max_video_frames = max_video_frames
        self.windows = self.prepare_windows()

    def __len__(self):
        return len(self.windows)

    def __getitem__(self, idx):
        window_info = self.windows[idx]
        audio_features, video_features, labels = self.get_window_data(window_info)
        return (audio_features, video_features), labels

    def prepare_windows(self):
        windows = []
        for video_id, video_group in self.video_df.groupby('path'):
            audio_group = self.audio_df[self.audio_df['filename'].str.contains(video_id)]
            max_time = video_group['timestamp'].max()
            window_starts = np.arange(0, max_time - self.window_size_sec + 1, self.stride_sec)

            for start in window_starts:
                end = start + self.window_size_sec
                window_audio = audio_group[(audio_group['start_timestep'] >= start) & (audio_group['end_timestep'] <= end)]
                window_video = video_group[(video_group['timestamp'] >= start) & (video_group['timestamp'] < end)]

                num_frames = len(window_video)
                if num_frames >= 2:  # Adjust this condition based on your requirement
                    # Adjust the window to include frames up to the max_video_frames
                    window_video = self.adjust_video_frames(window_video)
                    windows.append({'video_id': video_id, 'start': start, 'end': end})
                else:
                    print(f"Window rejected for video {video_id} at start={start} due to insufficient video frames.")

        return windows

    def adjust_video_frames(self, window_video):
        num_frames = len(window_video)
        if num_frames == self.max_video_frames:
            return window_video
        elif num_frames < self.max_video_frames:
            # Duplicate the last frame to reach max_video_frames
            num_duplicates = self.max_video_frames - num_frames
            duplicated_frames = pd.concat([window_video.iloc[-1]] * num_duplicates, ignore_index=True)
            window_video = pd.concat([window_video, duplicated_frames])
            return window_video

    def get_window_data(self, window_info):
        video_id = window_info['video_id']
        start = window_info['start']
        end = window_info['end']

        window_audio = self.audio_df[(self.audio_df['filename'].str.contains(video_id)) & (self.audio_df['start_timestep'] >= start) & (self.audio_df['end_timestep'] <= end)]
        window_video = self.video_df[(self.video_df['path'] == video_id) & (self.video_df['timestamp'] >= start) & (self.video_df['timestamp'] < end)]

        audio_features = window_audio.iloc[:, 5:].values
        video_features = window_video.iloc[:, 4:].values

        # Use last frame's arousal and valence as labels
        labels = window_video.iloc[-1, 2:4].values

        return audio_features, video_features, labels

# Load datasets
audio_train_df, audio_dev_df, audio_test_df, video_train_df, video_dev_df, video_test_df = load_datasets()

# Initialize DataLoader
custom_dataset = SynchronizedAVDataset(audio_train_df, video_train_df)
dataloader = DataLoader(custom_dataset, batch_size=32, shuffle=True)

# Example: Print first 20 rows of audio and video datasets for video 2117
print("First 20 rows of audio dataset for video 2117:")
print(audio_train_df[audio_train_df['filename'].str.contains('SEW2117')].head(20))
print("\nFirst 20 rows of video dataset for video 2117:")
print(video_train_df[video_train_df['path'].str.contains('SEW2117')].head(20))
# Out:
# Die letzten 5000 Zeilen der Streamingausgabe wurden abgeschnitten.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_111_86.png at start=100.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_111_86.png at start=101.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_111_86.png at start=102.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_111_86.png at start=103.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_111_86.png at start=104.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_111_86.png at start=105.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_111_86.png at start=106.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_111_86.png at start=107.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_111_86.png at start=108.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_111_86.png at start=109.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_111_86.png at start=110.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_2.png at start=0.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_2.png at start=1.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_2.png at start=2.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_2.png at start=3.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_2.png at start=4.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_2.png at start=5.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_2.png at start=6.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_2.png at start=7.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_2.png at start=8.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_2.png at start=9.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_2.png at start=10.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_2.png at start=11.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_2.png at start=12.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_2.png at start=13.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_2.png at start=14.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_2.png at start=15.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_2.png at start=16.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_2.png at start=17.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_2.png at start=18.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_2.png at start=19.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_2.png at start=20.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_2.png at start=21.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_2.png at start=22.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_2.png at start=23.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_2.png at start=24.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_2.png at start=25.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_2.png at start=26.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_2.png at start=27.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_2.png at start=28.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_2.png at start=29.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_2.png at start=30.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_2.png at start=31.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_2.png at start=32.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_2.png at start=33.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_2.png at start=34.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_2.png at start=35.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_2.png at start=36.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_2.png at start=37.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_2.png at start=38.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_2.png at start=39.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_2.png at start=40.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_2.png at start=41.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_2.png at start=42.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_2.png at start=43.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_2.png at start=44.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_2.png at start=45.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_2.png at start=46.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_2.png at start=47.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_2.png at start=48.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_2.png at start=49.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_2.png at start=50.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_2.png at start=51.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_2.png at start=52.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_2.png at start=53.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_2.png at start=54.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_2.png at start=55.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_2.png at start=56.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_2.png at start=57.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_2.png at start=58.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_2.png at start=59.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_2.png at start=60.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_2.png at start=61.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_2.png at start=62.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_2.png at start=63.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_2.png at start=64.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_2.png at start=65.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_2.png at start=66.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_2.png at start=67.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_2.png at start=68.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_2.png at start=69.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_2.png at start=70.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_2.png at start=71.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_2.png at start=72.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_2.png at start=73.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_2.png at start=74.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_2.png at start=75.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_2.png at start=76.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_2.png at start=77.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_2.png at start=78.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_2.png at start=79.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_2.png at start=80.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_2.png at start=81.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_2.png at start=82.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_2.png at start=83.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_2.png at start=84.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_2.png at start=85.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_2.png at start=86.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_2.png at start=87.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_2.png at start=88.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_2.png at start=89.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_2.png at start=90.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_2.png at start=91.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_2.png at start=92.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_2.png at start=93.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_2.png at start=94.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_2.png at start=95.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_2.png at start=96.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_2.png at start=97.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_2.png at start=98.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_2.png at start=99.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_2.png at start=100.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_2.png at start=101.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_2.png at start=102.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_2.png at start=103.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_2.png at start=104.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_2.png at start=105.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_2.png at start=106.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_2.png at start=107.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_2.png at start=108.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_2.png at start=109.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_2.png at start=110.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_2.png at start=111.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_54.png at start=0.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_54.png at start=1.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_54.png at start=2.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_54.png at start=3.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_54.png at start=4.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_54.png at start=5.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_54.png at start=6.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_54.png at start=7.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_54.png at start=8.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_54.png at start=9.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_54.png at start=10.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_54.png at start=11.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_54.png at start=12.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_54.png at start=13.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_54.png at start=14.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_54.png at start=15.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_54.png at start=16.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_54.png at start=17.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_54.png at start=18.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_54.png at start=19.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_54.png at start=20.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_54.png at start=21.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_54.png at start=22.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_54.png at start=23.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_54.png at start=24.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_54.png at start=25.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_54.png at start=26.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_54.png at start=27.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_54.png at start=28.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_54.png at start=29.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_54.png at start=30.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_54.png at start=31.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_54.png at start=32.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_54.png at start=33.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_54.png at start=34.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_54.png at start=35.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_54.png at start=36.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_54.png at start=37.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_54.png at start=38.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_54.png at start=39.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_54.png at start=40.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_54.png at start=41.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_54.png at start=42.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_54.png at start=43.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_54.png at start=44.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_54.png at start=45.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_54.png at start=46.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_54.png at start=47.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_54.png at start=48.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_54.png at start=49.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_54.png at start=50.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_54.png at start=51.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_54.png at start=52.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_54.png at start=53.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_54.png at start=54.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_54.png at start=55.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_54.png at start=56.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_54.png at start=57.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_54.png at start=58.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_54.png at start=59.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_54.png at start=60.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_54.png at start=61.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_54.png at start=62.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_54.png at start=63.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_54.png at start=64.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_54.png at start=65.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_54.png at start=66.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_54.png at start=67.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_54.png at start=68.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_54.png at start=69.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_54.png at start=70.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_54.png at start=71.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_54.png at start=72.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_54.png at start=73.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_54.png at start=74.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_54.png at start=75.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_54.png at start=76.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_54.png at start=77.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_54.png at start=78.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_54.png at start=79.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_54.png at start=80.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_54.png at start=81.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_54.png at start=82.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_54.png at start=83.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_54.png at start=84.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_54.png at start=85.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_54.png at start=86.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_54.png at start=87.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_54.png at start=88.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_54.png at start=89.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_54.png at start=90.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_54.png at start=91.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_54.png at start=92.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_54.png at start=93.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_54.png at start=94.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_54.png at start=95.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_54.png at start=96.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_54.png at start=97.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_54.png at start=98.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_54.png at start=99.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_54.png at start=100.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_54.png at start=101.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_54.png at start=102.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_54.png at start=103.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_54.png at start=104.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_54.png at start=105.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_54.png at start=106.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_54.png at start=107.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_54.png at start=108.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_54.png at start=109.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_54.png at start=110.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_54.png at start=111.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_88.png at start=0.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_88.png at start=1.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_88.png at start=2.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_88.png at start=3.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_88.png at start=4.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_88.png at start=5.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_88.png at start=6.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_88.png at start=7.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_88.png at start=8.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_88.png at start=9.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_88.png at start=10.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_88.png at start=11.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_88.png at start=12.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_88.png at start=13.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_88.png at start=14.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_88.png at start=15.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_88.png at start=16.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_88.png at start=17.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_88.png at start=18.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_88.png at start=19.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_88.png at start=20.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_88.png at start=21.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_88.png at start=22.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_88.png at start=23.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_88.png at start=24.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_88.png at start=25.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_88.png at start=26.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_88.png at start=27.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_88.png at start=28.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_88.png at start=29.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_88.png at start=30.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_88.png at start=31.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_88.png at start=32.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_88.png at start=33.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_88.png at start=34.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_88.png at start=35.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_88.png at start=36.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_88.png at start=37.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_88.png at start=38.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_88.png at start=39.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_88.png at start=40.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_88.png at start=41.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_88.png at start=42.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_88.png at start=43.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_88.png at start=44.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_88.png at start=45.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_88.png at start=46.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_88.png at start=47.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_88.png at start=48.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_88.png at start=49.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_88.png at start=50.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_88.png at start=51.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_88.png at start=52.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_88.png at start=53.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_88.png at start=54.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_88.png at start=55.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_88.png at start=56.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_88.png at start=57.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_88.png at start=58.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_88.png at start=59.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_88.png at start=60.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_88.png at start=61.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_88.png at start=62.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_88.png at start=63.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_88.png at start=64.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_88.png at start=65.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_88.png at start=66.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_88.png at start=67.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_88.png at start=68.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_88.png at start=69.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_88.png at start=70.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_88.png at start=71.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_88.png at start=72.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_88.png at start=73.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_88.png at start=74.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_88.png at start=75.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_88.png at start=76.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_88.png at start=77.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_88.png at start=78.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_88.png at start=79.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_88.png at start=80.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_88.png at start=81.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_88.png at start=82.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_88.png at start=83.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_88.png at start=84.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_88.png at start=85.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_88.png at start=86.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_88.png at start=87.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_88.png at start=88.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_88.png at start=89.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_88.png at start=90.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_88.png at start=91.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_88.png at start=92.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_88.png at start=93.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_88.png at start=94.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_88.png at start=95.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_88.png at start=96.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_88.png at start=97.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_88.png at start=98.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_88.png at start=99.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_88.png at start=100.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_88.png at start=101.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_88.png at start=102.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_88.png at start=103.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_88.png at start=104.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_88.png at start=105.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_88.png at start=106.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_88.png at start=107.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_88.png at start=108.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_88.png at start=109.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_88.png at start=110.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_112_88.png at start=111.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_113_22.png at start=0.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_113_22.png at start=1.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_113_22.png at start=2.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_113_22.png at start=3.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_113_22.png at start=4.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_113_22.png at start=5.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_113_22.png at start=6.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_113_22.png at start=7.0 due to insufficient video frames.
# ...
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_126_14.png at start=2.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_126_14.png at start=3.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_126_14.png at start=4.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_126_14.png at start=5.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_126_14.png at start=6.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_126_14.png at start=7.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_126_14.png at start=8.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_126_14.png at start=9.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_126_14.png at start=10.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_126_14.png at start=11.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_126_14.png at start=12.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_126_14.png at start=13.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_126_14.png at start=14.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_126_14.png at start=15.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_126_14.png at start=16.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_126_14.png at start=17.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_126_14.png at start=18.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_126_14.png at start=19.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_126_14.png at start=20.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_126_14.png at start=21.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_126_14.png at start=22.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_126_14.png at start=23.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_126_14.png at start=24.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_126_14.png at start=25.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_126_14.png at start=26.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_126_14.png at start=27.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_126_14.png at start=28.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_126_14.png at start=29.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_126_14.png at start=30.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_126_14.png at start=31.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_126_14.png at start=32.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_126_14.png at start=33.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_126_14.png at start=34.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_126_14.png at start=35.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_126_14.png at start=36.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_126_14.png at start=37.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_126_14.png at start=38.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_126_14.png at start=39.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_126_14.png at start=40.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_126_14.png at start=41.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_126_14.png at start=42.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_126_14.png at start=43.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_126_14.png at start=44.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_126_14.png at start=45.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_126_14.png at start=46.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_126_14.png at start=47.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_126_14.png at start=48.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_126_14.png at start=49.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_126_14.png at start=50.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_126_14.png at start=51.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_126_14.png at start=52.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_126_14.png at start=53.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_126_14.png at start=54.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_126_14.png at start=55.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_126_14.png at start=56.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_126_14.png at start=57.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_126_14.png at start=58.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_126_14.png at start=59.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_126_14.png at start=60.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_126_14.png at start=61.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_126_14.png at start=62.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_126_14.png at start=63.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_126_14.png at start=64.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_126_14.png at start=65.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_126_14.png at start=66.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_126_14.png at start=67.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_126_14.png at start=68.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_126_14.png at start=69.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_126_14.png at start=70.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_126_14.png at start=71.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_126_14.png at start=72.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_126_14.png at start=73.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_126_14.png at start=74.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_126_14.png at start=75.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_126_14.png at start=76.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_126_14.png at start=77.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_126_14.png at start=78.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_126_14.png at start=79.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_126_14.png at start=80.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_126_14.png at start=81.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_126_14.png at start=82.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_126_14.png at start=83.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_126_14.png at start=84.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_126_14.png at start=85.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_126_14.png at start=86.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_126_14.png at start=87.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_126_14.png at start=88.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_126_14.png at start=89.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_126_14.png at start=90.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_126_14.png at start=91.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_126_14.png at start=92.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_126_14.png at start=93.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_126_14.png at start=94.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_126_14.png at start=95.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_126_14.png at start=96.0 due to insufficient video frames.
# Window rejected for video /work/home/dsu/Datasets/SEWA/preprocessed/SEW1101_126_14.png at start=97.0 due to insufficient video frames.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-dbfea9270830> in <cell line: 89>()
#      87
#      88 # Initialize DataLoader
# ---> 89 custom_dataset = SynchronizedAVDataset(audio_train_df, video_train_df)
#      90 dataloader = DataLoader(custom_dataset, batch_size=32, shuffle=True)
#      91
#
# <ipython-input-9-dbfea9270830> in __init__(self, audio_df, video_df, window_size_sec, stride_sec, max_video_frames)
#      24         self.stride_sec = stride_sec
#      25         self.max_video_frames = max_video_frames
# ---> 26         self.windows = self.prepare_windows()
#      27
#      28     def __len__(self):
#
# <ipython-input-9-dbfea9270830> in prepare_windows(self)
#      43             for start in window_starts:
#      44                 end = start + self.window_size_sec
# ---> 45                 window_audio = audio_group[(audio_group['start_timestep'] >= start) & (audio_group['end_timestep'] <= end)]
#      46                 window_video = video_group[(video_group['timestamp'] >= start) & (video_group['timestamp'] < end)]
#      47
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3796         # Do we have a (boolean) 1d indexer?
#    3797         if com.is_bool_indexer(key):
# -> 3798             return self._getitem_bool_array(key)
#    3799
#    3800         # We are left with two options: a single key, and a collection of keys,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in _getitem_bool_array(self, key)
#    3851         key = check_bool_indexer(self.index, key)
#    3852         indexer = key.nonzero()[0]
# -> 3853         return self._take_with_is_copy(indexer, axis=0)
#    3854
#    3855     def _getitem_multilevel(self, key):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in _take_with_is_copy(self, indices, axis)
#    3902         result = self._take(indices=indices, axis=axis)
#    3903         # Maybe set copy if we didn't actually change the index.
# -> 3904         if not result._get_axis(axis).equals(self._get_axis(axis)):
#    3905             result._set_is_copy(self)
#    3906         return result
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in equals(self, other)
#    5527             return False
#    5528
# -> 5529         if is_object_dtype(self.dtype) and not is_object_dtype(other.dtype):
#    5530             # if other is not object, use other's logic for coercion
#    5531             return other.equals(self)
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/properties.pyx in pandas._libs.properties.CachedProperty.__get__()
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in dtype(self)
#     984         return Index(result, name=self.name)
#     985
# --> 986     @cache_readonly
#     987     def dtype(self) -> DtypeObj:
#     988         """
#
# KeyboardInterrupt:

# %%
import pandas as pd
import torch
from torch.utils.data import Dataset, DataLoader

class SynchronizedAudioVideoDataset(Dataset):
    def __init__(self, video_df, audio_df, window_length=2, step=1, max_frames=None):
        """
        Initializes the dataset object.
        :param video_df: DataFrame containing video data.
        :param audio_df: DataFrame containing audio data.
        :param window_length: Length of the time window in seconds.
        :param step: Step size to move the window in seconds.
        :param max_frames: Maximum number of frames to include in a window. If None, it will be calculated.
        """
        self.video_df = video_df
        self.audio_df = audio_df
        self.window_length = window_length
        self.step = step
        self.max_frames = max_frames
        self.data = self._synchronize()

    def _synchronize(self):
        """
        Synchronizes audio and video data based on the specified window_length and step.
        :return: List of tuples containing synchronized video and audio data along with labels for each window.
        """
        synchronized_data = []
        if self.max_frames is None:
            self.max_frames = self._calculate_max_frames()

        video_ids = self.video_df['path'].apply(lambda x: x.split('/')[-2]).unique()
        for video_id in video_ids:
            video_data = self.video_df[self.video_df['path'].str.contains(video_id)]
            audio_data = self.audio_df[self.audio_df['filename'].str.contains(video_id.split('_')[0])]

            start_time = 0
            while True:
                end_time = start_time + self.window_length
                window_video_data = video_data[(video_data['timestamp'] >= start_time) & (video_data['timestamp'] < end_time)]
                window_audio_data = audio_data[(audio_data['start_timestep'] >= start_time) & (audio_data['end_timestep'] <= end_time)]

                if len(window_video_data) > 0 and len(window_audio_data) > 0:
                    if len(window_video_data) < self.max_frames:
                        # Repeat the last row to match max_frames
                        additional_rows = self.max_frames - len(window_video_data)
                        last_row = window_video_data.iloc[-1:].copy()
                        for _ in range(additional_rows):
                            window_video_data = pd.concat([window_video_data, last_row], ignore_index=True)

                    labels = window_video_data.iloc[-1][['arousal', 'valence']].values
                    video_features = window_video_data.iloc[:, 3:].values  # Excluding path, timestamp, arousal, valence
                    audio_features = window_audio_data.iloc[:, 5:].values  # Excluding filename, start_timestep, end_timestep, arousal, valence, features

                    synchronized_data.append((video_features, audio_features, labels))

                start_time += self.step
                if start_time + self.window_length > video_data['timestamp'].max():
                    break

        return synchronized_data

    def _calculate_max_frames(self):
        """
        Calculates the maximum number of frames within any window across all videos.
        :return: Maximum number of frames within a window.
        """
        max_frames = 0
        video_ids = self.video_df['path'].apply(lambda x: x.split('/')[-2]).unique()
        for video_id in video_ids:
            video_data = self.video_df[self.video_df['path'].str.contains(video_id)]
            start_time = 0
            while True:
                end_time = start_time + self.window_length
                window_video_data = video_data[(video_data['timestamp'] >= start_time) & (video_data['timestamp'] < end_time)]
                max_frames = max(max_frames, len(window_video_data))
                start_time += self.step
                if start_time + self.window_length > video_data['timestamp'].max():
                    break
        return max_frames

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        video_features, audio_features, labels = self.data[idx]
        return torch.tensor(video_features, dtype=torch.float), torch.tensor(audio_features, dtype=torch.float), torch.tensor(labels, dtype=torch.float)

# Load video and audio data
video_train_df = pd.read_csv('/content/drive/MyDrive/SEWA_radiant_fog_160_train.csv')
video_dev_df = pd.read_csv('/content/drive/MyDrive/SEWA_radiant_fog_160_dev.csv')
video_test_df = pd.read_csv('/content/drive/MyDrive/SEWA_radiant_fog_160_test.csv')

audio_train_df = pd.read_csv('/content/drive/MyDrive/1sec/SEWA_features_wav2vec_1_seconds_train.csv')
audio_dev_df = pd.read_csv('/content/drive/MyDrive/1sec/SEWA_features_wav2vec_1_seconds_dev.csv')
audio_test_df = pd.read_csv('/content/drive/MyDrive/1sec/SEWA_features_wav2vec_1_seconds_test.csv')

# Create dataset instances
train_dataset = SynchronizedAudioVideoDataset(video_train_df, audio_train_df)
dev_dataset = SynchronizedAudioVideoDataset(video_dev_df, audio_dev_df)
test_dataset = SynchronizedAudioVideoDataset(video_test_df, audio_test_df)

# Create DataLoader instances
batch_size = 1  # Set to 1 for demonstration purposes, can be increased as needed
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
dev_loader = DataLoader(dev_dataset, batch_size=batch_size, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# Display the first 10 entries from the train_loader to verify synchronization
for i, (video_features, audio_features, labels) in enumerate(train_loader):
    if i >= 10:
        break
    print(f"Sample {i+1}: Video features shape: {video_features.shape}, Audio features shape: {audio_features.shape}, Labels: {labels.numpy()}")
# Out:
#                                                 path  timestamp   arousal  \
# 0  /work/home/dsu/Datasets/SEWA/preprocessed/SEW1...       2.04  0.294194
# 1  /work/home/dsu/Datasets/SEWA/preprocessed/SEW1...       2.38  0.335762
# 2  /work/home/dsu/Datasets/SEWA/preprocessed/SEW1...       2.72  0.395458
# 3  /work/home/dsu/Datasets/SEWA/preprocessed/SEW1...       3.06  0.419050
# 4  /work/home/dsu/Datasets/SEWA/preprocessed/SEW1...       3.40  0.420003
#
#     valence     emb_0     emb_1     emb_2     emb_3     emb_4     emb_5  ...  \
# 0  0.330165  0.000092 -0.000697  0.078171 -0.000050 -0.000146 -0.533671  ...
# 1  0.408600  0.000097 -0.000782  0.025183  0.001174  0.000013 -0.032633  ...
# 2  0.414567  0.000091 -0.000815  0.010308  0.000997  0.000059 -0.063469  ...
# 3  0.415242  0.000097 -0.000853 -0.011648  0.000785  0.000045  0.147162  ...
# 4  0.386110  0.000099 -0.000661  0.155788 -0.000450 -0.000002  0.000105  ...
#
#     emb_246   emb_247   emb_248   emb_249   emb_250   emb_251   emb_252  \
# 0  0.000312  0.000625  0.000035  0.654218 -0.996944  0.000028  0.001518
# 1  0.000435  0.000334  0.000035  0.516561 -0.995212  0.000020  0.001552
# 2  0.000373  0.000218  0.000035  0.536721 -0.985959  0.000021  0.001660
# 3  0.000411  0.000229  0.000031 -0.325153 -0.989091  0.000016  0.002085
# 4  0.000353  0.000346  0.000033  0.407132 -0.984939  0.000022  0.001722
#
#     emb_253   emb_254   emb_255
# 0  0.000032 -0.687274 -0.000585
# 1  0.000063 -0.833125 -0.000759
# 2  0.000070 -0.763110 -0.000735
# 3  0.000058 -0.876193 -0.000657
# 4  0.000053 -0.860464 -0.000594
#
# [5 rows x 260 columns]
#                                          filename  start_timestep  \
# 0  /work/home/dsu/Datasets/SEWA/audio/SEW1101.wav             0.0
# 1  /work/home/dsu/Datasets/SEWA/audio/SEW1101.wav             1.0
# 2  /work/home/dsu/Datasets/SEWA/audio/SEW1101.wav             2.0
# 3  /work/home/dsu/Datasets/SEWA/audio/SEW1101.wav             3.0
# 4  /work/home/dsu/Datasets/SEWA/audio/SEW1101.wav             4.0
#
#    end_timestep   arousal   valence  features       x_0       x_1       x_2  \
# 0          0.99  0.069682  0.000000       NaN -0.072897  0.002067  0.171740
# 1          1.99  0.289680  0.315083       NaN -0.076561  0.011748  0.031308
# 2          2.99  0.418364  0.416254       NaN -0.009226  0.002203 -0.032764
# 3          3.99  0.393300  0.285306       NaN -0.037265 -0.007950  0.089631
# 4          4.99  0.256235  0.215973       NaN -0.019666  0.024242 -0.020480
#
#         x_3  ...     x_758     x_759     x_760     x_761     x_762     x_763  \
# 0 -0.039302  ...  0.139346 -0.054141 -0.112815  0.280597 -0.293145  0.000861
# 1 -0.077866  ...  0.265668 -0.055287 -0.020320  0.442153 -0.263152 -0.006163
# 2 -0.067221  ...  0.236319 -0.056110 -0.053254  0.394420 -0.360009  0.001394
# 3 -0.055752  ...  0.194469 -0.052152 -0.093884  0.356597 -0.207222 -0.006739
# 4 -0.037980  ...  0.192281 -0.054829 -0.057758  0.173721 -0.196372  0.002582
#
#       x_764     x_765     x_766     x_767
# 0 -0.012984 -0.122969 -0.000401 -0.110178
# 1 -0.011856  0.014565 -0.008225 -0.080227
# 2 -0.012047 -0.105393 -0.019488 -0.054505
# 3 -0.011744 -0.240672 -0.015567 -0.036216
# 4 -0.015311 -0.069752  0.006805 -0.009604
#
# [5 rows x 774 columns]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-b32f371c35d8> in <cell line: 106>()
#     104 # Create DataLoader instances
#     105 batch_size = 1  # Set to 1 for demonstration purposes, can be increased as needed
# --> 106 train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
#     107 dev_loader = DataLoader(dev_dataset, batch_size=batch_size, shuffle=False)
#     108 test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py in __init__(self, dataset, batch_size, shuffle, sampler, batch_sampler, num_workers, collate_fn, pin_memory, drop_last, timeout, worker_init_fn, multiprocessing_context, generator, prefetch_factor, persistent_workers, pin_memory_device)
#     347             else:  # map-style
#     348                 if shuffle:
# --> 349                     sampler = RandomSampler(dataset, generator=generator)  # type: ignore[arg-type]
#     350                 else:
#     351                     sampler = SequentialSampler(dataset)  # type: ignore[arg-type]
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/sampler.py in __init__(self, data_source, replacement, num_samples, generator)
#     138
#     139         if not isinstance(self.num_samples, int) or self.num_samples <= 0:
# --> 140             raise ValueError(f"num_samples should be a positive integer value, but got num_samples={self.num_samples}")
#     141
#     142     @property
#
# ValueError: num_samples should be a positive integer value, but got num_samples=0

# %%
import pandas as pd
import torch
from torch.utils.data import Dataset, DataLoader

# Adjusted class to consider the path difference
class SynchronizedAudioVideoDataset(Dataset):
    def __init__(self, video_df, audio_df, window_length=2, step=1, max_frames=None):
        self.video_df = video_df
        self.audio_df = audio_df
        self.window_length = window_length
        self.step = step
        self.max_frames = max_frames
        self.data = self._synchronize()

    def _extract_video_id(self, path):
        # This function extracts the video ID from the video file path.
        # Adjust the slicing as per your directory structure if needed.
        return path.split('/')[-1].split('_')[0]

    def _synchronize(self):
        synchronized_data = []
        if self.max_frames is None:
            self.max_frames = self._calculate_max_frames()

        video_ids = self.video_df['path'].apply(self._extract_video_id).unique()
        for video_id in video_ids:
            video_data = self.video_df[self.video_df['path'].apply(lambda x: self._extract_video_id(x) == video_id)]
            audio_data = self.audio_df[self.audio_df['filename'].str.contains(video_id)]

            start_time = 0
            while True:
                end_time = start_time + self.window_length
                window_video_data = video_data[(video_data['timestamp'] >= start_time) & (video_data['timestamp'] < end_time)]
                window_audio_data = audio_data[(audio_data['start_timestep'] >= start_time) & (audio_data['end_timestep'] <= end_time)]

                if len(window_video_data) > 0 and len(window_audio_data) > 0:
                    if len(window_video_data) < self.max_frames:
                        additional_rows = self.max_frames - len(window_video_data)
                        last_row = window_video_data.iloc[-1:].copy()
                        for _ in range(additional_rows):
                            window_video_data = pd.concat([window_video_data, last_row], ignore_index=True)

                    labels = window_video_data.iloc[-1][['arousal', 'valence']].values
                    video_features = window_video_data.iloc[:, 3:].values
                    audio_features = window_audio_data.iloc[:, 5:].values

                    synchronized_data.append((video_features, audio_features, labels))

                start_time += self.step
                if start_time + self.window_length > video_data['timestamp'].max():
                    break

        return synchronized_data

    def _calculate_max_frames(self):
        """
        Calculates the maximum number of frames within any window across all videos.
        :return: Maximum number of frames within a window.
        """
        max_frames = 0
        video_ids = self.video_df['path'].apply(lambda x: x.split('/')[-2]).unique()
        for video_id in video_ids:
            video_data = self.video_df[self.video_df['path'].str.contains(video_id)]
            start_time = 0
            while True:
                end_time = start_time + self.window_length
                window_video_data = video_data[(video_data['timestamp'] >= start_time) & (video_data['timestamp'] < end_time)]
                max_frames = max(max_frames, len(window_video_data))
                start_time += self.step
                if start_time + self.window_length > video_data['timestamp'].max():
                    break
        return max_frames

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        video_features, audio_features, labels = self.data[idx]
        return torch.tensor(video_features, dtype=torch.float), torch.tensor(audio_features, dtype=torch.float), torch.tensor(labels, dtype=torch.float)

# Load video and audio data
video_train_df = pd.read_csv('/content/drive/MyDrive/SEWA_radiant_fog_160_train.csv')
video_dev_df = pd.read_csv('/content/drive/MyDrive/SEWA_radiant_fog_160_dev.csv')
video_test_df = pd.read_csv('/content/drive/MyDrive/SEWA_radiant_fog_160_test.csv')

audio_train_df = pd.read_csv('/content/drive/MyDrive/1sec/SEWA_features_wav2vec_1_seconds_train.csv')
audio_dev_df = pd.read_csv('/content/drive/MyDrive/1sec/SEWA_features_wav2vec_1_seconds_dev.csv')
audio_test_df = pd.read_csv('/content/drive/MyDrive/1sec/SEWA_features_wav2vec_1_seconds_test.csv')

# Create dataset instances
train_dataset = SynchronizedAudioVideoDataset(video_train_df, audio_train_df)
dev_dataset = SynchronizedAudioVideoDataset(video_dev_df, audio_dev_df)
test_dataset = SynchronizedAudioVideoDataset(video_test_df, audio_test_df)

# Create DataLoader instances
batch_size = 1  # For demonstration
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
dev_loader = DataLoader(dev_dataset, batch_size=batch_size, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# Display the first 10 entries from the train_loader
for i, (video_features, audio_features, labels) in enumerate(train_loader):
    if i >= 10:
        break
    print(f"Sample {i+1}: Video features shape: {video_features.shape}, Audio features shape: {audio_features.shape}, Labels: {labels.numpy()}")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-716e4212a1a3> in <cell line: 102>()
#     100
#     101 # Display the first 10 entries from the train_loader
# --> 102 for i, (video_features, audio_features, labels) in enumerate(train_loader):
#     103     if i >= 10:
#     104         break
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py in __next__(self)
#     628                 # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     629                 self._reset()  # type: ignore[call-arg]
# --> 630             data = self._next_data()
#     631             self._num_yielded += 1
#     632             if self._dataset_kind == _DatasetKind.Iterable and \
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py in _next_data(self)
#     672     def _next_data(self):
#     673         index = self._next_index()  # may raise StopIteration
# --> 674         data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     675         if self._pin_memory:
#     676             data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/_utils/fetch.py in fetch(self, possibly_batched_index)
#      49                 data = self.dataset.__getitems__(possibly_batched_index)
#      50             else:
# ---> 51                 data = [self.dataset[idx] for idx in possibly_batched_index]
#      52         else:
#      53             data = self.dataset[possibly_batched_index]
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/_utils/fetch.py in <listcomp>(.0)
#      49                 data = self.dataset.__getitems__(possibly_batched_index)
#      50             else:
# ---> 51                 data = [self.dataset[idx] for idx in possibly_batched_index]
#      52         else:
#      53             data = self.dataset[possibly_batched_index]
#
# <ipython-input-5-716e4212a1a3> in __getitem__(self, idx)
#      77     def __getitem__(self, idx):
#      78         video_features, audio_features, labels = self.data[idx]
# ---> 79         return torch.tensor(video_features, dtype=torch.float), torch.tensor(audio_features, dtype=torch.float), torch.tensor(labels, dtype=torch.float)
#      80
#      81 # Load video and audio data
#
# TypeError: can't convert np.ndarray of type numpy.object_. The only supported types are: float64, float32, float16, complex64, complex128, int64, int32, int16, int8, uint8, and bool.

# %%
import pandas as pd
import numpy as np
import torch
from torch.utils.data import Dataset, DataLoader

# Adjusted class to consider the path difference
class SynchronizedAudioVideoDataset(Dataset):
    def __init__(self, video_df, audio_df, window_length=2, step=1, max_frames=None):
        self.video_df = video_df
        self.audio_df = audio_df
        self.window_length = window_length
        self.step = step
        self.max_frames = max_frames
        self.data = self._synchronize()

    def _extract_video_id(self, path):
        # This function extracts the video ID from the video file path.
        # Adjust the slicing as per your directory structure if needed.
        return path.split('/')[-1].split('_')[0]

    def _synchronize(self):
        synchronized_data = []
        if self.max_frames is None:
            self.max_frames = self._calculate_max_frames()

        video_ids = self.video_df['path'].apply(self._extract_video_id).unique()
        for video_id in video_ids:
            video_data = self.video_df[self.video_df['path'].apply(lambda x: self._extract_video_id(x) == video_id)]
            audio_data = self.audio_df[self.audio_df['filename'].str.contains(video_id)]

            start_time = 0
            while True:
                end_time = start_time + self.window_length
                window_video_data = video_data[(video_data['timestamp'] >= start_time) & (video_data['timestamp'] < end_time)]
                window_audio_data = audio_data[(audio_data['start_timestep'] >= start_time) & (audio_data['end_timestep'] <= end_time)]

                if len(window_video_data) > 0 and len(window_audio_data) > 0:
                    if len(window_video_data) < self.max_frames:
                        additional_rows = self.max_frames - len(window_video_data)
                        last_row = window_video_data.iloc[-1:].copy()
                        for _ in range(additional_rows):
                            window_video_data = pd.concat([window_video_data, last_row], ignore_index=True)

                    labels = window_video_data.iloc[-1][['arousal', 'valence']].values
                    video_features = window_video_data.iloc[:, 3:].values
                    audio_features = window_audio_data.iloc[:, 5:].values

                    synchronized_data.append((video_features, audio_features, labels))

                start_time += self.step
                if start_time + self.window_length > video_data['timestamp'].max():
                    break

        return synchronized_data

    def _calculate_max_frames(self):
        """
        Calculates the maximum number of frames within any window across all videos.
        :return: Maximum number of frames within a window.
        """
        max_frames = 0
        video_ids = self.video_df['path'].apply(lambda x: x.split('/')[-2]).unique()
        for video_id in video_ids:
            video_data = self.video_df[self.video_df['path'].str.contains(video_id)]
            start_time = 0
            while True:
                end_time = start_time + self.window_length
                window_video_data = video_data[(video_data['timestamp'] >= start_time) & (video_data['timestamp'] < end_time)]
                max_frames = max(max_frames, len(window_video_data))
                start_time += self.step
                if start_time + self.window_length > video_data['timestamp'].max():
                    break
        return max_frames

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        video_features, audio_features, labels = self.data[idx]

        print(f"Video features type: {type(video_features)}, shape: {video_features.shape}")
        print(f"Audio features type: {type(audio_features)}, shape: {audio_features.shape}")
        print(f"Labels type: {type(labels)}, shape: {labels.shape}")

        # Ensure video_features and audio_features are numpy arrays of type float
        video_features = np.array(video_features, dtype=np.float32)
        audio_features = np.array(audio_features, dtype=np.float32)

        # Convert labels to numpy array if it's not already
        labels = np.array(labels, dtype=np.float32)

        return torch.tensor(video_features, dtype=torch.float), torch.tensor(audio_features, dtype=torch.float), torch.tensor(labels, dtype=torch.float)


# Load video and audio data
video_train_df = pd.read_csv('/content/drive/MyDrive/SEWA_radiant_fog_160_train.csv')
video_dev_df = pd.read_csv('/content/drive/MyDrive/SEWA_radiant_fog_160_dev.csv')
video_test_df = pd.read_csv('/content/drive/MyDrive/SEWA_radiant_fog_160_test.csv')

audio_train_df = pd.read_csv('/content/drive/MyDrive/1sec/SEWA_features_wav2vec_1_seconds_train.csv')
audio_dev_df = pd.read_csv('/content/drive/MyDrive/1sec/SEWA_features_wav2vec_1_seconds_dev.csv')
audio_test_df = pd.read_csv('/content/drive/MyDrive/1sec/SEWA_features_wav2vec_1_seconds_test.csv')

# Create dataset instances
train_dataset = SynchronizedAudioVideoDataset(video_train_df, audio_train_df)
dev_dataset = SynchronizedAudioVideoDataset(video_dev_df, audio_dev_df)
test_dataset = SynchronizedAudioVideoDataset(video_test_df, audio_test_df)

# Create DataLoader instances
batch_size = 1  # For demonstration
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
dev_loader = DataLoader(dev_dataset, batch_size=batch_size, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# Display the first 10 entries from the train_loader
for i, (video_features, audio_features, labels) in enumerate(train_loader):
    if i >= 10:
        break
    print(f"Sample {i+1}: Video features shape: {video_features.shape}, Audio features shape: {audio_features.shape}, Labels: {labels.numpy()}")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-724d2041991f> in <cell line: 105>()
#     103
#     104 # Create dataset instances
# --> 105 train_dataset = SynchronizedAudioVideoDataset(video_train_df, audio_train_df)
#     106 dev_dataset = SynchronizedAudioVideoDataset(video_dev_df, audio_dev_df)
#     107 test_dataset = SynchronizedAudioVideoDataset(video_test_df, audio_test_df)
#
# <ipython-input-1-724d2041991f> in __init__(self, video_df, audio_df, window_length, step, max_frames)
#      12         self.step = step
#      13         self.max_frames = max_frames
# ---> 14         self.data = self._synchronize()
#      15
#      16     def _extract_video_id(self, path):
#
# <ipython-input-1-724d2041991f> in _synchronize(self)
#      40                         last_row = window_video_data.iloc[-1:].copy()
#      41                         for _ in range(additional_rows):
# ---> 42                             window_video_data = pd.concat([window_video_data, last_row], ignore_index=True)
#      43
#      44                     labels = window_video_data.iloc[-1][['arousal', 'valence']].values
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/reshape/concat.py in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     366     1   3   4
#     367     """
# --> 368     op = _Concatenator(
#     369         objs,
#     370         axis=axis,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/reshape/concat.py in __init__(self, objs, axis, join, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     561         self.copy = copy
#     562
# --> 563         self.new_axes = self._get_new_axes()
#     564
#     565     def get_result(self):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/reshape/concat.py in _get_new_axes(self)
#     631     def _get_new_axes(self) -> list[Index]:
#     632         ndim = self._get_result_dim()
# --> 633         return [
#     634             self._get_concat_axis if i == self.bm_axis else self._get_comb_axis(i)
#     635             for i in range(ndim)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/reshape/concat.py in <listcomp>(.0)
#     632         ndim = self._get_result_dim()
#     633         return [
# --> 634             self._get_concat_axis if i == self.bm_axis else self._get_comb_axis(i)
#     635             for i in range(ndim)
#     636         ]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/reshape/concat.py in _get_comb_axis(self, i)
#     638     def _get_comb_axis(self, i: int) -> Index:
#     639         data_axis = self.objs[0]._get_block_manager_axis(i)
# --> 640         return get_objs_combined_axis(
#     641             self.objs,
#     642             axis=data_axis,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/api.py in get_objs_combined_axis(objs, intersect, axis, sort, copy)
#     103     """
#     104     obs_idxes = [obj._get_axis(axis) for obj in objs]
# --> 105     return _get_combined_index(obs_idxes, intersect=intersect, sort=sort, copy=copy)
#     106
#     107
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/api.py in _get_combined_index(indexes, intersect, sort, copy)
#     156             index = index.intersection(other)
#     157     else:
# --> 158         index = union_indexes(indexes, sort=False)
#     159         index = ensure_index(index)
#     160
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/api.py in union_indexes(indexes, sort)
#     226         return result
#     227
# --> 228     indexes, kind = _sanitize_and_check(indexes)
#     229
#     230     def _unique_indices(inds, dtype) -> Index:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/api.py in _sanitize_and_check(indexes)
#     358             return indexes, "list"
#     359
# --> 360     if len(kinds) > 1 or Index not in kinds:
#     361         return indexes, "special"
#     362     else:
#
# KeyboardInterrupt:

# %%
import pandas as pd
import numpy as np
import torch
from torch.utils.data import Dataset, DataLoader

# Adjusted class to consider the path difference
class SynchronizedAudioVideoDataset(Dataset):
    def __init__(self, video_df, audio_df, window_length=2, step=1, max_frames=None):
        self.video_df = video_df
        self.audio_df = audio_df
        self.window_length = window_length
        self.step = step
        self.max_frames = max_frames
        self.data = self._synchronize()

    def _extract_video_id(self, path):
        # This function extracts the video ID from the video file path.
        # Adjust the slicing as per your directory structure if needed.
        return path.split('/')[-1].split('_')[0]

    def _synchronize(self):
        synchronized_data = []
        if self.max_frames is None:
            self.max_frames = self._calculate_max_frames()

        video_ids = self.video_df['path'].apply(self._extract_video_id).unique()
        for video_id in video_ids:
            video_data = self.video_df[self.video_df['path'].apply(lambda x: self._extract_video_id(x) == video_id)]
            audio_data = self.audio_df[self.audio_df['filename'].str.contains(video_id)]

            start_time = 0
            while True:
                end_time = start_time + self.window_length
                window_video_data = video_data[(video_data['timestamp'] >= start_time) & (video_data['timestamp'] < end_time)]
                window_audio_data = audio_data[(audio_data['start_timestep'] >= start_time) & (audio_data['end_timestep'] <= end_time)]

                if len(window_video_data) > 0 and len(window_audio_data) > 0:
                    if len(window_video_data) < self.max_frames:
                        additional_rows = self.max_frames - len(window_video_data)
                        last_row = window_video_data.iloc[-1:].copy()
                        for _ in range(additional_rows):
                            window_video_data = pd.concat([window_video_data, last_row], ignore_index=True)

                    labels = window_video_data.iloc[-1][['arousal', 'valence']].values
                    video_features = window_video_data.iloc[:, 3:].values
                    audio_features = window_audio_data.iloc[:, 5:].values

                    synchronized_data.append((video_features, audio_features, labels))

                start_time += self.step
                if start_time + self.window_length > video_data['timestamp'].max():
                    break

        return synchronized_data

    def _calculate_max_frames(self):
        """
        Calculates the maximum number of frames within any window across all videos.
        :return: Maximum number of frames within a window.
        """
        max_frames = 0
        video_ids = self.video_df['path'].apply(lambda x: x.split('/')[-2]).unique()
        for video_id in video_ids:
            video_data = self.video_df[self.video_df['path'].str.contains(video_id)]
            start_time = 0
            while True:
                end_time = start_time + self.window_length
                window_video_data = video_data[(video_data['timestamp'] >= start_time) & (video_data['timestamp'] < end_time)]
                max_frames = max(max_frames, len(window_video_data))
                start_time += self.step
                if start_time + self.window_length > video_data['timestamp'].max():
                    break
        return max_frames

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        video_features, audio_features, labels = self.data[idx]

        print(f"Video features type: {type(video_features)}, shape: {video_features.shape}")
        print(f"Audio features type: {type(audio_features)}, shape: {audio_features.shape}")
        print(f"Labels type: {type(labels)}, shape: {labels.shape}")

        # Ensure video_features and audio_features are numpy arrays of type float
        video_features = np.array(video_features, dtype=np.float32)
        audio_features = np.array(audio_features, dtype=np.float32)

        # Convert labels to numpy array if it's not already
        labels = np.array(labels, dtype=np.float32)

        return torch.tensor(video_features, dtype=torch.float), torch.tensor(audio_features, dtype=torch.float), torch.tensor(labels, dtype=torch.float)


# Load video and audio data
video_train_df = pd.read_csv('/content/drive/MyDrive/SEWA_radiant_fog_160_train.csv')
video_dev_df = pd.read_csv('/content/drive/MyDrive/SEWA_radiant_fog_160_dev.csv')
video_test_df = pd.read_csv('/content/drive/MyDrive/SEWA_radiant_fog_160_test.csv')

audio_train_df = pd.read_csv('/content/drive/MyDrive/1sec/SEWA_features_wav2vec_1_seconds_train.csv')
audio_dev_df = pd.read_csv('/content/drive/MyDrive/1sec/SEWA_features_wav2vec_1_seconds_dev.csv')
audio_test_df = pd.read_csv('/content/drive/MyDrive/1sec/SEWA_features_wav2vec_1_seconds_test.csv')

# Create dataset instances
train_dataset = SynchronizedAudioVideoDataset(video_train_df, audio_train_df)
dev_dataset = SynchronizedAudioVideoDataset(video_dev_df, audio_dev_df)
test_dataset = SynchronizedAudioVideoDataset(video_test_df, audio_test_df)

# Create DataLoader instances
batch_size = 1  # For demonstration
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
dev_loader = DataLoader(dev_dataset, batch_size=batch_size, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# Assuming you have your DataLoader setup as before
for i, (video_features, audio_features, labels) in enumerate(train_loader):
    if i >= 10:  # Just to limit the output to the first 10 batches
        break

    # Convert tensors to numpy for easy slicing and displaying
    video_features_np = video_features.numpy()
    audio_features_np = audio_features.numpy()
    labels_np = labels.numpy()

    # Print the first few rows of each. Adjust the number of rows as needed
    num_rows_to_display = 3  # for example, to display the first 3 rows

    print(f"Batch {i+1}")
    print(f"Video Features (first {num_rows_to_display} rows):")
    print(video_features_np[:num_rows_to_display])

    print(f"Audio Features (first {num_rows_to_display} rows):")
    # Note: If the second dimension represents a time or sequence dimension, you may need to adjust this
    print(audio_features_np[:, :num_rows_to_display])  # Assuming the first dimension is batch

    print("Labels:")
    print(labels_np)  # Labels might be just one per sample, depending on your data structure
    print("\n----------\n")
